# %% [markdown]
# <a href="https://colab.research.google.com/github/omar-bluebug/test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download Image
#
# This notebook downloads the flower image and saves it as `success.jpg`.

# %%
import requests
from pathlib import Path

image_url = "https://bouqs.com/blog/wp-content/uploads/2022/03/shutterstock_260182148-min.jpg"
output_path = Path("success.jpg")

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(image_url, headers=headers, timeout=30)
response.raise_for_status()

output_path.write_bytes(response.content)

print(f"Downloaded image to: {output_path.resolve()}")
